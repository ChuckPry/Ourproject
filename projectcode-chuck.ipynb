# %%
import pandas as pd
import numpy as np

# %% [markdown]
# import pandas as pd
# tsv_file='rt.reviews.tsv'
# csv_table=pd.read_table(tsv_file,sep='\t')
# csv_table.to_csv('new_name.csv',index=False)

# %%
df5 = pd.read_csv('rt.movie_info.tsv', sep = '\t')
df5
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df = pd.read_csv('tn.movie_budgets.csv')
df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
pd.concat([df5, dfff], axis=1, join='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-42213fe45b23> in <module>
# ----> 1 pd.concat([df5, dfff], axis=1, join='inner')
#
# NameError: name 'dfff' is not defined

# %%
df.shape
# Out:
# (5782, 6)

# %%
print(df.info)
print(df.columns)
print(df.dtypes)
# Out:
# <bound method DataFrame.info of       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]>
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
thu = df.iloc[:, 2:6]
thu
# Out:
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625  $2,776,345,279
# 1      $241,063,875  $1,045,663,875
# 2       $42,762,350    $149,762,350
# 3      $459,005,868  $1,403,013,963
# 4      $620,181,382  $1,316,721,747
# ...             ...             ...
# 5777             $0              $0
# 5778        $48,482        $240,495
# 5779         $1,338          $1,338
# 5780             $0              $0
# 5781       $181,041        $181,041
#
# [5782 rows x 4 columns]

# %%
s = dfff['production_budget']
s.head(25)
# Out:
# 0     [, 425,000,000]
# 1     [, 410,600,000]
# 2     [, 350,000,000]
# 3     [, 330,600,000]
# 4     [, 317,000,000]
# 5     [, 306,000,000]
# 6     [, 300,000,000]
# 7     [, 300,000,000]
# 8     [, 300,000,000]
# 9     [, 300,000,000]
# 10    [, 275,000,000]
# 11    [, 275,000,000]
# 12    [, 275,000,000]
# 13    [, 275,000,000]
# 14    [, 260,000,000]
# 15    [, 258,000,000]
# 16    [, 250,000,000]
# 17    [, 250,000,000]
# 18    [, 250,000,000]
# 19    [, 250,000,000]
# 20    [, 250,000,000]
# 21    [, 250,000,000]
# 22    [, 250,000,000]
# 23    [, 232,000,000]
# 24    [, 230,000,000]
# Name: production_budget, dtype: object

# %%
v = dfff['worldwide_gross']
v
# Out:
# 0       [, 2,776,345,279]
# 1       [, 1,045,663,875]
# 2         [, 149,762,350]
# 3       [, 1,403,013,963]
# 4       [, 1,316,721,747]
#               ...
# 5777                [, 0]
# 5778          [, 240,495]
# 5779            [, 1,338]
# 5780                [, 0]
# 5781          [, 181,041]
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
fv = s.map(lambda x: x[1])
g = fv.map(lambda x: x.strip())
y = g.map(lambda x: x.replace(',', ''))
prod_budget = y.astype(float)
prod_budget
# Out:
# 0       425000000.0
# 1       410600000.0
# 2       350000000.0
# 3       330600000.0
# 4       317000000.0
#            ...
# 5777         7000.0
# 5778         6000.0
# 5779         5000.0
# 5780         1400.0
# 5781         1100.0
# Name: production_budget, Length: 5782, dtype: float64

# %%
jh = v.map(lambda x: x[1])
c = jh.map(lambda x: x.strip())
z = c.map(lambda x: x.replace(',', ''))
worldwide_gross1 = z.astype(float)
worldwide_gross1
# Out:
# 0       2.776345e+09
# 1       1.045664e+09
# 2       1.497624e+08
# 3       1.403014e+09
# 4       1.316722e+09
#             ...
# 5777    0.000000e+00
# 5778    2.404950e+05
# 5779    1.338000e+03
# 5780    0.000000e+00
# 5781    1.810410e+05
# Name: worldwide_gross, Length: 5782, dtype: float64

# %%
thu['prod_budget'] = prod_budget
thu
thu['world_gross'] = worldwide_gross1
thu
# Out:
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross  prod_budget   world_gross
# 0      $760,507,625  $2,776,345,279  425000000.0  2.776345e+09
# 1      $241,063,875  $1,045,663,875  410600000.0  1.045664e+09
# 2       $42,762,350    $149,762,350  350000000.0  1.497624e+08
# 3      $459,005,868  $1,403,013,963  330600000.0  1.403014e+09
# 4      $620,181,382  $1,316,721,747  317000000.0  1.316722e+09
# ...             ...             ...          ...           ...
# 5777             $0              $0       7000.0  0.000000e+00
# 5778        $48,482        $240,495       6000.0  2.404950e+05
# 5779         $1,338          $1,338       5000.0  1.338000e+03
# 5780             $0              $0       1400.0  0.000000e+00
# 5781       $181,041        $181,041       1100.0  1.810410e+05
#
# [5782 rows x 6 columns]

# %%
roi1 = thu['world_gross'].map(lambda x: x) - thu['prod_budget'].map(lambda y: y)
roi1
# Out:
# 0       2.351345e+09
# 1       6.350639e+08
# 2      -2.002376e+08
# 3       1.072414e+09
# 4       9.997217e+08
#             ...
# 5777   -7.000000e+03
# 5778    2.344950e+05
# 5779   -3.662000e+03
# 5780   -1.400000e+03
# 5781    1.799410e+05
# Length: 5782, dtype: float64

# %%
thu['roi'] = roi1
thu
# Out:
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross  prod_budget   world_gross           roi
# 0      $760,507,625  $2,776,345,279  425000000.0  2.776345e+09  2.351345e+09
# 1      $241,063,875  $1,045,663,875  410600000.0  1.045664e+09  6.350639e+08
# 2       $42,762,350    $149,762,350  350000000.0  1.497624e+08 -2.002376e+08
# 3      $459,005,868  $1,403,013,963  330600000.0  1.403014e+09  1.072414e+09
# 4      $620,181,382  $1,316,721,747  317000000.0  1.316722e+09  9.997217e+08
# ...             ...             ...          ...           ...           ...
# 5777             $0              $0       7000.0  0.000000e+00 -7.000000e+03
# 5778        $48,482        $240,495       6000.0  2.404950e+05  2.344950e+05
# 5779         $1,338          $1,338       5000.0  1.338000e+03 -3.662000e+03
# 5780             $0              $0       1400.0  0.000000e+00 -1.400000e+03
# 5781       $181,041        $181,041       1100.0  1.810410e+05  1.799410e+05
#
# [5782 rows x 7 columns]

# %%
wdf = thu.sort_values(by = ['roi'], ascending = False)
wdf
# Out:
#                                     movie production_budget domestic_gross  \
# 0                                  Avatar      $425,000,000   $760,507,625
# 42                                Titanic      $200,000,000   $659,363,944
# 6                  Avengers: Infinity War      $300,000,000   $678,815,482
# 5    Star Wars Ep. VII: The Force Awakens      $306,000,000   $936,662,225
# 33                         Jurassic World      $215,000,000   $652,270,625
# ..                                    ...               ...            ...
# 352                        Town & Country      $105,000,000     $6,712,451
# 341           Men in Black: International      $110,000,000     $3,100,000
# 193                       Mars Needs Moms      $150,000,000    $21,392,758
# 194                              Moonfall      $150,000,000             $0
# 2                            Dark Phoenix      $350,000,000    $42,762,350
#
#     worldwide_gross  prod_budget   world_gross           roi
# 0    $2,776,345,279  425000000.0  2.776345e+09  2.351345e+09
# 42   $2,208,208,395  200000000.0  2.208208e+09  2.008208e+09
# 6    $2,048,134,200  300000000.0  2.048134e+09  1.748134e+09
# 5    $2,053,311,220  306000000.0  2.053311e+09  1.747311e+09
# 33   $1,648,854,864  215000000.0  1.648855e+09  1.433855e+09
# ..              ...          ...           ...           ...
# 352     $10,364,769  105000000.0  1.036477e+07 -9.463523e+07
# 341      $3,100,000  110000000.0  3.100000e+06 -1.069000e+08
# 193     $39,549,758  150000000.0  3.954976e+07 -1.104502e+08
# 194              $0  150000000.0  0.000000e+00 -1.500000e+08
# 2      $149,762,350  350000000.0  1.497624e+08 -2.002376e+08
#
# [5782 rows x 7 columns]

# %%
wdf.drop([0:9])
# Out:
#   File "<ipython-input-50-80534977c723>", line 1
#     wdf.drop([0:9])
#                ^
# SyntaxError: invalid syntax

# %%
new_df = df.worldwide_gross.map(lambda x: x.split('$'))
type(new_df)
# Out:
# pandas.core.series.Series

# %%
dfff = thu.applymap(lambda x: x.split('$'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-94e533199960> in <module>
# ----> 1 dfff = thu.applymap(lambda x: x.split('$'))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in applymap(self, func)
#    6977             return lib.map_infer(x.astype(object).values, func)
#    6978
# -> 6979         return self.apply(infer)
#    6980
#    6981     # ----------------------------------------------------------------------
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in infer(x)
#    6975             if x.empty:
#    6976                 return lib.map_infer(x, func)
# -> 6977             return lib.map_infer(x.astype(object).values, func)
#    6978
#    6979         return self.apply(infer)
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-52-94e533199960> in <lambda>(x)
# ----> 1 dfff = thu.applymap(lambda x: x.split('$'))
#
# AttributeError: ("'float' object has no attribute 'split'", 'occurred at index prod_budget')

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
plt.figure(figsize=(30,10))


plt.scatter(prod_budget, worldwide_gross1, color = 'c')

plt.ylabel('Production Budget')
plt.xlabel('World Wide Sales')
plt.ticklabel_format(useOffset=False, style='plain')
plt.title('Total ROI for All Movies')
plt.rcParams.update({'font.size': 36})



plt.grid()
plt.show()

# %%
df6 = pd.read_csv('imdb.title.basics.csv')
df6
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
df7 = df6.drop(columns =['tconst', 'original_title','start_year', 'runtime_minutes'])

# %%
df7
# Out:
#                                       primary_title                genres
# 0                                         Sunghursh    Action,Crime,Drama
# 1                   One Day Before the Rainy Season       Biography,Drama
# 2                        The Other Side of the Wind                 Drama
# 3                                   Sabse Bada Sukh          Comedy,Drama
# 4                          The Wandering Soap Opera  Comedy,Drama,Fantasy
# ...                                             ...                   ...
# 146139                          Kuambil Lagi Hatiku                 Drama
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro           Documentary
# 146141                              Dankyavar Danka                Comedy
# 146142                                       6 Gunn                   NaN
# 146143               Chico Albuquerque - Revelações           Documentary
#
# [146144 rows x 2 columns]

# %%
result = pd.concat([wdf, df7], axis=1, join='inner')

# %%
jt = result.drop(columns = ['production_budget','domestic_gross','worldwide_gross'])

# %%
jt
# Out:
#                                     movie  prod_budget   world_gross  \
# 0                                  Avatar  425000000.0  2.776345e+09
# 42                                Titanic  200000000.0  2.208208e+09
# 6                  Avengers: Infinity War  300000000.0  2.048134e+09
# 5    Star Wars Ep. VII: The Force Awakens  306000000.0  2.053311e+09
# 33                         Jurassic World  215000000.0  1.648855e+09
# ..                                    ...          ...           ...
# 352                        Town & Country  105000000.0  1.036477e+07
# 341           Men in Black: International  110000000.0  3.100000e+06
# 193                       Mars Needs Moms  150000000.0  3.954976e+07
# 194                              Moonfall  150000000.0  0.000000e+00
# 2                            Dark Phoenix  350000000.0  1.497624e+08
#
#               roi               primary_title                    genres
# 0    2.351345e+09                   Sunghursh        Action,Crime,Drama
# 42   2.008208e+09                     My Land              Drama,Family
# 6    1.748134e+09                     Bigfoot           Horror,Thriller
# 5    1.747311e+09                 A Thin Life                    Comedy
# 33   1.433855e+09               Mortal Kombat  Action,Adventure,Fantasy
# ..            ...                         ...                       ...
# 352 -9.463523e+07                     Neowolf           Horror,Thriller
# 341 -1.069000e+08                    The Town      Crime,Drama,Thriller
# 193 -1.104502e+08                   Abhishapt                     Drama
# 194 -1.500000e+08         Season of the Witch  Action,Adventure,Fantasy
# 2   -2.002376e+08  The Other Side of the Wind                     Drama
#
# [5782 rows x 6 columns]
